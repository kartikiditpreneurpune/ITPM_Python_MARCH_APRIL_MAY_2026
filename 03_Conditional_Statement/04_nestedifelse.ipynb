# %%
# accept the username and password 
# username== admin and password==admin@1234

username=input("ENter Username :: ")
password=input("ENter Password  :: ")

if username=="admin":
    if password=="admin@1234":
        print("Login Successful ")
    else:
        print("Incorrect PAssword ")
else:
    print("Invalid Username")
# Out:
# Invalid Username

# %%
# Online Shopping Offer 

bill_amount=float(input("Enter Bill aMount :: "))
prime_member=input("Enter Prime Membership :: yes/no")

if bill_amount>=10000:
    if prime_member=="yes":
        print("Extra 10 % Discount")
    else:
        print("5% Discount")
else:
    print("No Discount Applicable!!")

# %%
# employee bonus -- if exp > 5 and salary is >80000 eligible for bonus
# marks >75 and entrnace_exam is clear -- eligible for course
# if age >18 and if citizen of india can vote
