# %%
# accept a string and display it 

user=input("Enter User NAme :: ")
password=input("Enter Password :: ")

print("="*30)
print("Name is :: ",user)
print("Password is :: ",password)
# Out:
# ==============================
# Name is ::  Kartiki
# Password is ::  kartiki@1234

# %%
# calculate the length of string

str=input("Enter User NAme :: ")

print("Length of String is :: ",len(str))
# Out:
# Length of String is ::  7

# %%
# convert string to uppercase , lowercase and capitalize 

str=input("Enter String :: ")

print("String in Uppercase is :: ",str.upper())

print("String in Lowercase is :: ",str.lower())

print("String in Capitalize is :: ",str.capitalize())

print("String in TitleCase is :: ",str.title())
# Out:
# String in Uppercase is ::  INDIA IS MY COUNTRY
# String in Lowercase is ::  india is my country
# String in Capitalize is ::  India is my country
# String in TitleCase is ::  India Is My Country

# %%
# count the number of words in string

str=input("Enter String :: ")
word=input("Enter Word to Count :: ")

print("String is :: ",str)
print("Count of words is :: ",str.count(word))
# Out:
# Count of words is ::  2

# %%
# find the word from string
str=input("Enter String :: ")
word=input("Enter Word to Find :: ")

print("String is :: ",str)
print("Index of Word is :: ",str.find(word))
# Out:
# Index of Word is ::  19

# %%
# join the string 

words=["India","is","my","Country"]
res=" ".join(words)
print("String is :: ",res)

res="-".join(words)
print("String is :: ",res)

res=":".join(words)
print("String is :: ",res)

res=",".join(words)
print("String is :: ",res)

res="|".join(words)
print("String is :: ",res)

res="=".join(words)
print("String is :: ",res)

# separtors " " - : , |
# Out:
# String is ::  India is my Country
# String is ::  India-is-my-Country
# String is ::  India:is:my:Country
# String is ::  India,is,my,Country
# String is ::  India|is|my|Country
# String is ::  India=is=my=Country

# %%
# strip :: trim the whitespaces 

str=input("Enter String :: ")

print("String is :: ",str.strip())
# Out:
# String is ::  India

# %%
# check whether a string contains only digit -- only for digit in string 
str=input("Enter String :: ")

if str.isdigit():
    print("It contains digit in string")
else:
    print("Its is a Pure String ")
# Out:
# It contains digit in string

# %%
# check whether a string contains only alphabet
str=input("Enter String :: ")

if str.isalpha():
    print("It contains digit in string")
else:
    print("Its is a Pure String ")
# Out:
# Its is a Pure String

# %%
# check whether a string contains digits with aplahebts
str=input("Enter String :: ")

if str.isalnum():
    print("It contains digit in string")
else:
    print("Its is a Pure String ")
# Out:
# It contains digit in string

# %%
# check string starts from which word and ends with which 

str=input("Enter String :: ")
word=input("Enter Word to check :: ")

if str.startswith(word):
    print("Yes it starts with word ")
else:
    print("It doesn't start with the given word ")


if str.endswith(word):
    print("Yes it ends with word ")
else:
    print("It doesn't ends with the given word ")
# Out:
# Yes it starts with word
# It doesn't ends with the given word

# %% [markdown]
#  Requirements (Must Use All String Functions)
#
# The program should:
#   1. Accept full name from the user
#   2. Display the length of the name
#   3. Convert the name to uppercase, lowercase, title case, and capitalized form
#   4. Count how many times a letter appears in the name
#   5. Find the position of a word or letter
#   6. Replace a word/letter in the name
#   7. Split the name into a list of words
#   8. Join the words back into a single string#
#   9. Remove extra spaces using strip()
#   10. Check whether the name:
#   • contains only alphabets
#   • starts with a given letter
#   • ends with a given letter
#   11. Accept mobile number and check:
#   • digits only (isdigit())
#   • alphanumeric (isalnum())

# %%
# Requirements (Must Use All String Functions)

# The program should:
#  1. Accept full name from the user
#  2. Display the length of the name
#  3. Convert the name to uppercase, lowercase, title case, and capitalized form
#  4. Count how many times a letter appears in the name
#  5. Find the position of a word or letter
#  6. Replace a word/letter in the name
#  7. Split the name into a list of words
#  8. Join the words back into a single string
#  9. Remove extra spaces using strip()
#  10. Check whether the name:
#  • contains only alphabets
#  • starts with a given letter
#  • ends with a given letter
#  11. Accept mobile number and check:
#  • digits only (isdigit())
#  • alphanumeric (isalnum())



# User Profile Text Analyzer

name = input("Enter your full name: ")

# 1. strip()
name = name.strip()

# 2. len()
print("Length of name:", len(name))

# 3. upper(), lower()
print("Uppercase:", name.upper())
print("Lowercase:", name.lower())

# 4. title(), capitalize()
print("Title Case:", name.title())
print("Capitalized:", name.capitalize())

# 5. count()
ch = input("Enter a letter to count: ")
print("Count:", name.count(ch))

# 6. find()
find_word = input("Enter a word/letter to find: ")
print("Position:", name.find(find_word))

# 7. replace()
old = input("Enter letter/word to replace: ")
new = input("Enter new letter/word: ")
print("Updated Name:", name.replace(old, new))

# 8. split()
words = name.split()
print("Split words:", words)

# 9. join()
joined_name = " ".join(words)
print("Joined Name:", joined_name)

# 10. isalpha()
if name.replace(" ", "").isalpha():
    print("Name contains only alphabets")
else:
    print("Name contains other characters")

# 11. startswith()
start = input("Enter starting letter to check: ")
print("Starts with:", name.startswith(start))

# 12. endswith()
end = input("Enter ending letter to check: ")
print("Ends with:", name.endswith(end))

# Mobile number validation
mobile = input("Enter mobile number: ")

# 13. isdigit()
if mobile.isdigit():
    print("Mobile number contains only digits")
else:
    print("Mobile number is invalid")

# 14. isalnum()
if mobile.isalnum():
    print("Mobile number is alphanumeric")
else:
    print("Mobile number is not alphanumeric")

# %%
# count the vowels 

str=input("Enter String :: ")
count=0

for ch in str.lower():
    if ch in "aeiou":
        count=count+1


print("Total Vowel Count is :: ",count)
# Out:
# Total Vowel Count is ::  3

# %%
# String Slicing 

str="India is my Country"

print(str[3])
print(str[1:5])
print(str[2:])
print(str[:6])
print(str[:])
print(str[-3])
print(str[-5:-2])
# print(str[50])
# IndexError: string index out of range
# Out:
# i
# ndia
# dia is my Country
# India
# India is my Country
# t
# unt

# %%
# reverse the string 

str=input("Enter the string :: ")
print("Reversed string is :: ",str[::-1])
# Out:
# Reversed string is ::  aidnI

# %%
# Palindrome String
str=input("Enter the string :: ")

if str==str[::-1]:
    print("Palindrome String")
else:
    print("NOT a Palindrome String ")
# Out:
# Palindrome String

# %%
# count the characters in string

str=input("Enter the string :: ")
character=input("Enter Character :: ")

print("Occurance of character is :: ",str.lower().count(character))
# Out:
# Occurance of character is ::  3

# %%
# find the substring

str=input("Enter the string :: ")

substr=input("Enter Substring :: ")

print("Found at index :: ",str.find(substr))
# Out:
# Found at index ::  12

# %%
# replace word 

str=input("Enter the string :: ")
print("Replaced String is :: ",str.replace("Java","Python"))
# Out:
# Replaced String is ::  I am a Python Developer

# %%
# remove the spaces 

str=input("Enter the string :: ")
print("String without spaces is :: ",str.replace(" ",""))
# Out:
# String without spaces is ::  IndiaismyCountry

# %%
# accept the string from user and split and join it 
str=input("Enter the string :: ")

word=str.split()
print("List of Words :: ",word)

print("Joined Words are :: ","-".join(word))
# Out:
# List of Words ::  ['India', 'is', 'my', 'COuntry']
# Joined Words are ::  India-is-my-COuntry
